# %%
# oops project

class ATM:
    def __init__(self,bank_name):
        self.pin='0000'
        self.balance=2000
        print(f'welcome to {bank_name} bank'.upper().center(70,' '))


        pin_ans=input('enter your pin:')
        
        if pin_ans == self.pin:
            
            
            ans = input('''select any one option give below 
            1>> withdrawl
            2>> deposit
            3>> pin change
            4>> check balance
            5>> cancel:
            ''') 


            if ans == '1':
                self.withdrawl()
          
            elif ans == '2':
                self.deposit()
            
            elif ans == '3':
                self.pin_change()
            
            elif ans == '4':
                self.check_balance()
            
            elif ans == '5':
                self.cancel()
            else:
                print('invalid choice!!!')
        else:
            print('invaild PIN!!!')
            exit()

    #-----------------------------------------------------------init
        
        def withdrawl(self):
           amount=input('enter amount:')
            if amount.isdigit():
                amount=int(amount)
                if amount<=self.balance:
                    if amount % 100 == 0:
                        if amount<=50000:
                            print(f'amount rs {amount} withdrawl sucessfully')
                            self.balamce -= amount
                            self.check_balance()
                        else:
                            print('darily limit exceed!!')
                    else:
                        print('amount must be multiple of rs 100')
                else:
                    print('insufficient balance!!')
            else:
                print('amount must be numerical')
    #------------------------------------------------------------withdrawl    
        
        def deposit(self):
           deposit_amount = input('enter amount:')
           if deposit_amount.isdigit():
               if deposit_amount % 100 == 0:
                   print(f'amount rs {amount} withdrawl sucessfully')
                   self.balance += desposit_amount
                   self.check_balance()
               else:
                   print('amount must be multiple os rs 100')
            else:
                print('amount must be numerical')
    

        def change_pin(self):
            pin_input = input('enter old PIN:')
            if pin_input == self.pin:
                new_pin_1=input('create new PIN:')
                new_pin_2=input('enter again:')
    
                
                if new_pin_1.isdigit() and len(new_pin_1)==4:
                    new_pin_2 = input('enter again:')
                    if new_pin_1 == new_pin_2:
                        phone=input('enter registered phone number:')
                        if phone.isdigit() and len(phone)==10:
                            import random
                            otp=random.randint(1111,9999)
                            print('otp sending',end='')

                            
                            for i in range(5):
                                print('.',end ='')
                                time.sleep(1)
                                
                            diplay(clear=True)
                            print('your otp is: ',otp)
                            
                            otp_ans=input('enter otp:')
                            if otp_ans==otp:
                                self.pin=new_pin_1
                                print('PIN changed sucessfully!!')
                            else:
                                print('incorrect otp')
                        else:
                            print('invalid phone number')
                    else:
                        print('PIN mismatched!!')
                else:
                    print('invalid PIN!!')
            else:
                print('incorrect PIN')
            
        
        def check_balance(self):
           print(f'your current balance is rs {self.balance}')
        
        def cancel(self):
            print('sucessfully canceled!!')
# Out:
#   File <string>:75
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
import time
print('otp sending',end='')
for i in range(5):
    print('.',end = ' ')
    time.sleep(1)
# Out:
# otp sending. . . . .
